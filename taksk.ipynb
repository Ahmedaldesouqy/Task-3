# %%
import pandas as pd
import numpy as np
BigMart_Sales_Train=pd.read_csv('C:/Users/DELL/Desktop/BigMart-Sales-Train.csv')
BigMart_Sales_Train
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
np.random.seed(0)

# %%
BigMart_Sales_Train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
BigMart_Sales_Train.head(6)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# ...

# %%
BigMart_Sales_Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
BigMart_Sales_Train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
BigMart_Sales_Train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
BigMart_Sales_Train.duplicated().sum()
# Out:
# 0

# %%
BigMart_Sales_Train.drop_duplicates(inplace=True)
BigMart_Sales_Train.duplicated().sum()
# Out:
# 0

# %%
for x in BigMart_Sales_Train.index:
    if (BigMart_Sales_Train.loc[x, 'Item_Type'] == 0):
        BigMart_Sales_Train.drop(x, inplace = True)

# %%
BigMart_Sales_Train['Item_Identifier'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0       FDA15
# 1       DRC01
# 2       FDN15
# 3       FDX07
# 4       NCD19
#         ...
# 8518    FDF22
# 8519    FDS36
# 8520    NCJ29
# 8521    FDN46
# 8522    DRG01
# Name: Item_Identifier, Length: 8523, dtype: object>

# %%
BigMart_Sales_Train.drop(columns=['Item_Identifier','Outlet_Identifier'], inplace=True)

# %%
BigMart_Sales_Train.shape
# Out:
# (8523, 10)

# %%
BigMart_Sales_Train_count =BigMart_Sales_Train.isnull().sum()
BigMart_Sales_Train_count[0:10]
# Out:
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
total_cell =np.product(BigMart_Sales_Train.shape)
total_missing = BigMart_Sales_Train_count.sum()
print(total_missing)
# Out:
# 3873

# %%
total_cell =np.product(BigMart_Sales_Train.shape)
total_missing = BigMart_Sales_Train_count.sum()

precent_missing =(total_missing / total_cell )*100
print(precent_missing)
# Out:
# 4.544174586413234

# %%
BigMart_Sales_Train.dropna()
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility           Item_Type  \
# 0           9.300          Low Fat         0.016047               Dairy
# 1           5.920          Regular         0.019278         Soft Drinks
# 2          17.500          Low Fat         0.016760                Meat
# 4           8.930          Low Fat         0.000000           Household
# 5          10.395          Regular         0.000000        Baking Goods
# ...           ...              ...              ...                 ...
# 8517       20.750              reg         0.083607        Frozen Foods
# 8518        6.865          Low Fat         0.056783         Snack Foods
# 8520       10.600          Low Fat         0.035186  Health and Hygiene
# 8521        7.210          Regular         0.145221         Snack Foods
# 8522       14.800          Low Fat         0.044878         Soft Drinks
#
#       Item_MRP  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# ...

# %%
columns_with_na_dropped = BigMart_Sales_Train.dropna(axis=1)
columns_with_na_dropped.head()
# Out:
#   Item_Fat_Content  Item_Visibility              Item_Type  Item_MRP  \
# 0          Low Fat         0.016047                  Dairy  249.8092
# 1          Regular         0.019278            Soft Drinks   48.2692
# 2          Low Fat         0.016760                   Meat  141.6180
# 3          Regular         0.000000  Fruits and Vegetables  182.0950
# 4          Low Fat         0.000000              Household   53.8614
#
#    Outlet_Establishment_Year Outlet_Location_Type        Outlet_Type  \
# 0                       1999               Tier 1  Supermarket Type1
# 1                       2009               Tier 3  Supermarket Type2
# 2                       1999               Tier 1  Supermarket Type1
# 3                       1998               Tier 3      Grocery Store
# 4                       1987               Tier 3  Supermarket Type1
#
#    Item_Outlet_Sales
# 0          3735.1380
# 1           443.4228
# 2          2097.2700
# 3           732.3800
# 4           994.7052

# %%
BigMart_Sales_Train['Outlet_Establishment_Year'].dtype
BigMart_Sales_Train
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
BigMart_Sales_Train['Outlet_Establishment_Year'] = pd.to_datetime(BigMart_Sales_Train['Outlet_Establishment_Year'])
BigMart_Sales_Train['year'] = BigMart_Sales_Train['Outlet_Establishment_Year'].dt.year

# %%
BigMart_Sales_Train
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(BigMart_Sales_Train.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
BigMart_Sales_Train['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
sns.countplot(x='Item_Fat_Content',data=BigMart_Sales_Train)
plt.title('sales')
plt.show()

# %%
plt.pie(BigMart_Sales_Train['Item_Fat_Content'].value_counts(),labels=BigMart_Sales_Train['Item_Fat_Content'].value_counts().index,autopct ='%1.2f%%',shadow = True)
plt.title('precentage of Item_Fat_Conten')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title('Average Demand (Low Fat/Regular)')
sns.barplot(x='Item_Fat_Content', y='Item_MRP', data=BigMart_Sales_Train)
# Out:
# <AxesSubplot:title={'center':'Average Demand (Low Fat/Regular)'}, xlabel='Item_Fat_Content', ylabel='Item_MRP'>

# %%
plt.figure(figsize=(10,10))
sns.countplot(data = BigMart_Sales_Train  , x = 'Item_Fat_Content', order=BigMart_Sales_Train.Item_Fat_Content.value_counts().index)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='count'>

# %%
plt.pie(BigMart_Sales_Train['Item_Visibility'].value_counts(),labels=BigMart_Sales_Train['Item_Visibility'].value_counts().index,autopct ='%1.2f%%',shadow = True, )
plt.title('sales')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=BigMart_Sales_Train, x = 'Item_Fat_Content', order = BigMart_Sales_Train.Item_Fat_Content.value_counts().index)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='count'>

# %%
plt.figure(figsize=(8,8))
plt.pie(BigMart_Sales_Train.Item_Fat_Content.value_counts(), labels = ['Low Fat', 'Regular', 'LF', 'reg', 'low fat'], autopct ='%1.f%%', shadow= True)
plt.title("The percentage of each Item")
plt.axis('equal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.scatterplot(x='Item_Weight', y = 'Item_Visibility', data=BigMart_Sales_Train)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.scatterplot(x='Item_MRP', y = 'Item_Visibility', data=BigMart_Sales_Train)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.scatterplot(x='Item_Fat_Content', y = 'Item_Visibility', data=BigMart_Sales_Train)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(25,15))
sns.barplot(x='Item_Type', y='Item_Visibility', hue='Item_Fat_Content', data =BigMart_Sales_Train)
plt.title("Item_Type comparison based on the Item_Visibility and the Item_Fat_Content")
plt.show()

# %%
BigMart_Sales_Train.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.000000  Fruits and Vegetables
# 4         8.93          Low Fat         0.000000              Household
#
#    Item_MRP     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0  249.8092 1970-01-01 00:00:00.000001999      Medium               Tier 1
# 1   48.2692 1970-01-01 00:00:00.000002009      Medium               Tier 3
# 2  141.6180 1970-01-01 00:00:00.000001999      Medium               Tier 1
# 3  182.0950 1970-01-01 00:00:00.000001998         NaN               Tier 3
# 4   53.8614 1970-01-01 00:00:00.000001987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales  year
# ...

# %%
plt.plot(BigMart_Sales_Train.groupby('Outlet_Establishment_Year').sum()['Item_MRP'], ls='-', lw=3, alpha=0.85)
plt.title("total Item_MRP of sales over the year")
plt.xlabel('Outlet_Establishment_Year', color = 'b', size=12)
plt.ylabel('Item_MRP', color = 'r', size=12)
plt.show()

# %%
a = BigMart_Sales_Train.loc[BigMart_Sales_Train.Item_Visibility.sort_values(ascending = False).head().index]
sns.catplot(data = a, kind = 'bar', height = 8, aspect = 2.4, x = 'Item_MRP', y='Item_Visibility')

# %%
plt.figure(figsize=(16,8))
sns.countplot(data= BigMart_Sales_Train , x='Item_MRP')
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='count'>

# %%
a = BigMart_Sales_Train.loc[BigMart_Sales_Train.Item_Visibility.sort_values(ascending = False).head().index]
sns.catplot(data = a, kind = 'bar', height = 5, aspect = 2, x = 'Item_Weight', y='Item_Visibility')

# %%
a = BigMart_Sales_Train.loc[BigMart_Sales_Train.Item_Visibility.sort_values(ascending = False).head().index]
sns.catplot(data = a, kind = 'bar', height = 8, aspect = 2.4, x = 'Item_MRP', y='Item_Visibility')
